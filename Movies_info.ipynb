# %%
import pandas as pd
from sqlalchemy import create_engine
import psycopg2

# %%
csv_file = 'data/Movies.csv'
Movies_info_df = pd.read_csv(csv_file)
Movies_info_df.head()
# Out:
#                            Name  RuntimeInMinutes  BudgetInMillions  \
# 0  The Lord of the Rings Series               558               281
# 1    The Fellowship of the Ring               178                93
# 2               The Two Towers                179                94
# 3        The Return of the King               201                94
# 4             The Hobbit Series               462               675
#
#    BoxOfficeRevenueInMillions  AcademyAwardNominations  AcademyAwardWins  \
# 0                      2917.0                       30                17
# 1                       871.5                       13                 4
# 2                       926.0                        6                 2
# 3                      1120.0                       11                11
# 4                      2932.0                        7                 1
#
#    RottenTomatoesScore
# 0            94.000000
# 1            91.000000
# 2            96.000000
# ...

# %%
Movies_filtered_df = Movies_info_df.drop(Movies_info_df.index[[4,5,6,7]])
Movies_filtered_df
# Out:
#                            Name  RuntimeInMinutes  BudgetInMillions  \
# 0  The Lord of the Rings Series               558               281
# 1    The Fellowship of the Ring               178                93
# 2               The Two Towers                179                94
# 3        The Return of the King               201                94
#
#    BoxOfficeRevenueInMillions  AcademyAwardNominations  AcademyAwardWins  \
# 0                      2917.0                       30                17
# 1                       871.5                       13                 4
# 2                       926.0                        6                 2
# 3                      1120.0                       11                11
#
#    RottenTomatoesScore
# 0                 94.0
# 1                 91.0
# 2                 96.0
# 3                 95.0

# %%
engine = create_engine("postgresql://postgres:{password}@localhost:5432/EtlProject_db".format(password=password))
conn = engine.connect()

Movies_filtered_df.to_sql(name='Movies_filtered_df', con=engine, if_exists='append', index=False)
